# %%
from pathlib import Path
import sys
import polars as pl

SERVER_PROJECT_ROOT = Path('~/workspace/paper_research').expanduser().resolve()
if str(SERVER_PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(SERVER_PROJECT_ROOT))

from utils.notebook_bootstrap import bootstrap_notebook

PROJECT_ROOT, DIR = bootstrap_notebook(preferred_root=SERVER_PROJECT_ROOT)

# %%
pl.read_parquet('/home/leekwanhyeong/workspace/paper_research/search_artifacts/titan_hparam_search/leaderboard/stage1_combo.parquet')
# Out:
# shape: (21, 20)
# ┌────────┬────────────┬─────────────┬─────────────┬───┬────────────┬─────────┬──────────┬──────────┐
# │ stage  ┆ scale_base ┆ candidate_n ┆ mean_datase ┆ … ┆ persistent ┆ use_lmm ┆ mem_size ┆ mem_topk │
# │ ---    ┆ ---        ┆ ame         ┆ t_rank      ┆   ┆ _mem_size  ┆ ---     ┆ ---      ┆ ---      │
# │ str    ┆ f64        ┆ ---         ┆ ---         ┆   ┆ ---        ┆ bool    ┆ i64      ┆ i64      │
# │        ┆            ┆ str         ┆ f64         ┆   ┆ i64        ┆         ┆          ┆          │
# ╞════════╪════════════╪═════════════╪═════════════╪═══╪════════════╪═════════╪══════════╪══════════╡
# │ stage1 ┆ 10.0       ┆ mid_no_lmm  ┆ 2.4         ┆ … ┆ 32         ┆ false   ┆ 128      ┆ 8        │
# │ stage1 ┆ 10.0       ┆ mid_deep_lm ┆ 5.4         ┆ … ┆ 32         ┆ true    ┆ 128      ┆ 8        │
# │        ┆            ┆ m           ┆             ┆   ┆            ┆         ┆          ┆          │
# │ stage1 ┆ 4.0        ┆ mid_deep_lm ┆ 5.6         ┆ … ┆ 32         ┆ true    ┆ 128      ┆ 8        │
# │        ┆            ┆ m           ┆             ┆   ┆            ┆         ┆          ┆          │
# │ stage1 ┆ 10.0       ┆ mid_lmm     ┆ 6.0         ┆ … ┆ 32         ┆ true    ┆ 128      ┆ 8        │
# │ stage1 ┆ 10.0       ┆ small_deep_ ┆ 6.2         ┆ … ┆ 16         ┆ true    ┆ 64       ┆ 4        │
# │        ┆            ┆ lmm         ┆             ┆   ┆            ┆         ┆          ┆          │
# │ …      ┆ …          ┆ …           ┆ …           ┆ … ┆ …          ┆ …       ┆ …        ┆ …        │
# │ stage1 ┆ 4.0        ┆ small_deep_ ┆ 14.7        ┆ … ┆ 16         ┆ true    ┆ 64       ┆ 4        │
# │        ┆            ┆ lmm         ┆             ┆   ┆            ┆         ┆          ┆          │
# │ stage1 ┆ 2.0        ┆ small_deep_ ┆ 17.35       ┆ … ┆ 16         ┆ true    ┆ 64       ┆ 4        │
# │        ┆            ┆ lmm         ┆             ┆   ┆            ┆         ┆          ┆          │
# │ stage1 ┆ 2.0        ┆ mid_no_lmm  ┆ 17.95       ┆ … ┆ 32         ┆ false   ┆ 128      ┆ 8        │
# │ stage1 ┆ 2.0        ┆ small_lmm   ┆ 18.95       ┆ … ┆ 16         ┆ true    ┆ 64       ┆ 4        │
# │ stage1 ┆ 2.0        ┆ small_no_lm ┆ 19.5        ┆ … ┆ 16         ┆ false   ┆ 64       ┆ 4        │
# │        ┆            ┆ m           ┆             ┆   ┆            ┆         ┆          ┆          │
# └────────┴────────────┴─────────────┴─────────────┴───┴────────────┴─────────┴──────────┴──────────┘
